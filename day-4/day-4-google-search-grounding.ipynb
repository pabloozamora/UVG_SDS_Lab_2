# %% [markdown]
# # Laboratorio 2 - GenAI

# %% [markdown]
# Universidad del Valle de Guatemala<br>
# Security Data Science - Sección 10<br>
# Pablo Andrés Zamora Vásquez<br>
# Carné 21780<br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# El resto del notebook no podía completarse sin pagar por la API:
#
# ![image.png](attachment:image.png)
